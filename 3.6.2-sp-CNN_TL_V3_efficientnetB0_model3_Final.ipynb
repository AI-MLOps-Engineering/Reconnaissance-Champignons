# %% [markdown]
# MODELE DE RESEAU DE NEURONES CONVOLUTIFS

# %%
'''
Modèle CNN avec Transfer Learning EfficientNetB0


'''
# Out:
# '\nModèle CNN avec Transfer Learning EfficientNetB0\n\n\n'

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.3.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (12.1.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.7/620.7 MB 5.7 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.0 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 141.5 MB/s eta 0:00:00
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 135.7 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 188.2 MB/s eta 0:00:00
# Downloading werkzeug-3.1.5-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 25.9 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wheel, werkzeug, tensorboard-data-server, google_pasta, tensorboard, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-25.12.19 google_pasta-0.2.0 libclang-18.1.1 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 werkzeug-3.1.5 wheel-0.45.1

# %%
# Import des librairies principales
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# Importation pour la transformation des images
from tensorflow.keras.layers import RandomTranslation
from tensorflow.keras.layers import RandomZoom
from tensorflow.keras.layers import RandomFlip
from tensorflow.keras.layers import RandomRotation
from tensorflow.keras.layers import RandomContrast


# Imports nécessaires pour construire / sauvegarder / évaluer le modèle
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
#rom tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Rescaling
from tensorflow.keras.layers import Resizing
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from tensorflow.keras import regularizers

from tensorflow.keras.layers import GlobalAveragePooling2D

#from tensorflow.keras.applications import ResNet50
#from tensorflow.keras.applications.resnet50 import preprocess_input

from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input



from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

from sklearn.metrics import classification_report, confusion_matrix


# Importation de l'utilitaire image_dataset_from_directory de Keras
from keras.utils import image_dataset_from_directory
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Définition des chemins d'accès

rep_img = '/content/gdrive/My Drive/Colab Notebooks/Champi gras Cake/DataScience_images_Especes3'
rep_model = "/content/gdrive/My Drive/Colab Notebooks/Champi gras Cake/models3/"

# %%
# Importation de l'utilitaire image_dataset_from_directory de Keras

train_ds = image_dataset_from_directory(
    rep_img,
    validation_split=0.30,     # 30% réservé pour val + test
    subset="training",
    seed=42,
    batch_size=64,
    image_size=(224, 224)
)

# Dataset temporaire qui va être divisé en 15% validation et 15% test
temp_ds = image_dataset_from_directory(
    rep_img,
    validation_split=0.30,
    subset="validation",
    seed=42,
    batch_size=64,
    image_size=(224, 224)
)
# Out:
# Found 25913 files belonging to 30 classes.
# Using 18140 files for training.
# Found 25913 files belonging to 30 classes.
# Using 7773 files for validation.

# %%
# Découpage du dataset temp en validation + test


temp_size = tf.data.experimental.cardinality(temp_ds).numpy()

val_size = temp_size // 2
test_size = temp_size - val_size

val_ds = temp_ds.take(val_size)
test_ds = temp_ds.skip(val_size)

# %%
# Optimisation du pipeline

AUTOTUNE = tf.data.AUTOTUNE   # Optimisation automatique du nombre de fichiers et threads à charger

train_ds = train_ds.cache().shuffle(1000).prefetch(AUTOTUNE) # Pour garder en mémoire les images et gagner en vitesse // shuffle pour mélanger les images à chaque epoch pour un meilleur apprentissage
val_ds   = val_ds.cache().prefetch(AUTOTUNE)
test_ds  = test_ds.cache().prefetch(AUTOTUNE)

# %%
# Nombre de lot dans l'ensemble d'entraînement
print("Nombre de batch dans train_ds:", train_ds.cardinality().numpy())

# Nombre de lot dans l'ensemble de validation
print("Nombre de batch dans val_ds:", val_ds.cardinality().numpy())

# Nombre de lot dans l'ensemble de test
print("Nombre de batch dans test_ds:", test_ds.cardinality().numpy())
# Out:
# Nombre de batch dans train_ds: 284
# Nombre de batch dans val_ds: 61
# Nombre de batch dans test_ds: 61

# %%
# Définir des couches de transformation
random_translation = RandomTranslation(0.1, 0.1)   # Étirement
random_zoom = RandomZoom(0.1)                      # Agrandissement
random_flip = RandomFlip("horizontal")             # Retournement horizontal
random_rotation = RandomRotation(0.1)              # Rotation
random_contrast = RandomContrast(0.1)              # Contraste

# %%
# Récupération de 16 images et affichage

for batch_images, batch_labels in train_ds.take(1):
    images = batch_images[:16]
    labels = batch_labels[:16]

plt.figure(figsize=(12, 32))

for i in range(16):
    image = images[i]  # Récupérer la ième image

    # Appliquer les transformations
    x = random_translation(image)   # Etirement
    x = random_zoom(x)              # Zoom
    x = random_flip(x)              # Retournement
    x = random_rotation(x)          # Rotation
    x = random_contrast(x)          # Contraste

    # Afficher l'image originale
    plt.subplot(16, 2, 2*i + 1)  # Position dans la grille
    plt.imshow(image.numpy().astype("uint8"))
    plt.axis("off")

    # Afficher l'image transformée
    plt.subplot(16, 2, 2*i + 2)  # Position dans la grille
    plt.imshow(x.numpy().astype("uint8"))
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
NUM_CLASSES = 30

inputs = Input(shape=(224, 224, 3))

# Data augmentation
x = random_translation(inputs)
x = random_zoom(x)
x = random_flip(x)
x = random_rotation(x)
x = random_contrast(x)

# Préprocess ResNet50 (à la place du Rescaling)
x = preprocess_input(x)

# Backbone ResNet50
base_model = EfficientNetB0(
    include_top=False,          # on enlève la couche de classification ImageNet
    weights="imagenet",
    input_tensor=x
)

base_model.trainable = False    # phase 1 : on gèle

# Tête de classification
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation="relu")(x)
x = Dropout(0.3)(x)
outputs = Dense(NUM_CLASSES, activation="softmax")(x)

model_efficientb0 = Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Callback pour sauvegarder le modèle
'''save = ModelCheckpoint(
                        rep_model+'CNN_TL_efficientb0_model.h5',
                        save_best_only=True,
                        monitor='val_loss',
                        mode='min'
                    )'''


save = tf.keras.callbacks.ModelCheckpoint(
    rep_model + "CNN_TL_model_efficientb0.keras",
    monitor="val_loss",
    mode="min",
    save_best_only=True
)



# Callback pour réduire le taux d'apprentissage
reduceLR = ReduceLROnPlateau(
                                monitor="val_loss",
                                mode="min",
                                patience=3,
                                factor=0.5,
                                min_delta=0.001,
                                cooldown=1,
                                min_lr=1e-6,
                                verbose=1
                                    )

# Callback pour stopper l'apprentissage quand il ne progresse plus
early_stop = EarlyStopping(
                                patience=6,     # Nombre d'époques sans amélioration avant arrêt
                                min_delta=0.001,
                                mode='min',
                                monitor='val_loss',    # On surveille la perte sur l'ensemble de validation
                                restore_best_weights=True)

# %%
model_efficientb0.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

# %%
history_model1 = model_efficientb0.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,                  # 15 voire 20
    callbacks=[reduceLR, save, early_stop]
)
# Out:
# Epoch 1/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 153s 524ms/step - accuracy: 0.4153 - loss: 2.1051 - val_accuracy: 0.6880 - val_loss: 1.0248 - learning_rate: 0.0010
# Epoch 2/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.6846 - loss: 1.0315 - val_accuracy: 0.7410 - val_loss: 0.8519 - learning_rate: 0.0010
# Epoch 3/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.7523 - loss: 0.8119 - val_accuracy: 0.7741 - val_loss: 0.7377 - learning_rate: 0.0010
# Epoch 4/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 271ms/step - accuracy: 0.7877 - loss: 0.7038 - val_accuracy: 0.8040 - val_loss: 0.6597 - learning_rate: 0.0010
# Epoch 5/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.8005 - loss: 0.6321 - val_accuracy: 0.8053 - val_loss: 0.6332 - learning_rate: 0.0010
# Epoch 6/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.8338 - loss: 0.5286 - val_accuracy: 0.8156 - val_loss: 0.6071 - learning_rate: 0.0010
# Epoch 7/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.8499 - loss: 0.4838 - val_accuracy: 0.8317 - val_loss: 0.5490 - learning_rate: 0.0010
# Epoch 8/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.8586 - loss: 0.4530 - val_accuracy: 0.8468 - val_loss: 0.5109 - learning_rate: 0.0010
# Epoch 9/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.8699 - loss: 0.4151 - val_accuracy: 0.8502 - val_loss: 0.4885 - learning_rate: 0.0010
# Epoch 10/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.8777 - loss: 0.3868 - val_accuracy: 0.8509 - val_loss: 0.4969 - learning_rate: 0.0010
# Epoch 11/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.8834 - loss: 0.3666 - val_accuracy: 0.8555 - val_loss: 0.4859 - learning_rate: 0.0010
# Epoch 12/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.8937 - loss: 0.3392 - val_accuracy: 0.8548 - val_loss: 0.4883 - learning_rate: 0.0010
# Epoch 13/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 76s 269ms/step - accuracy: 0.8964 - loss: 0.3233 - val_accuracy: 0.8417 - val_loss: 0.5227 - learning_rate: 0.0010
# Epoch 14/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.8986 - loss: 0.3162 - val_accuracy: 0.8637 - val_loss: 0.4776 - learning_rate: 0.0010
# Epoch 15/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 270ms/step - accuracy: 0.9055 - loss: 0.2914 - val_accuracy: 0.8548 - val_loss: 0.4790 - learning_rate: 0.0010
# Epoch 16/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 77s 271ms/step - accuracy: 0.9104 - loss: 0.2799 - val_accuracy: 0.8709 - val_loss: 0.4468 - learning_rate: 0.0010
# Epoch 17/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 76s 269ms/step - accuracy: 0.9125 - loss: 0.2711 - val_accuracy: 0.8584 - val_loss: 0.4641 - learning_rate: 0.0010
# Epoch 18/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 76s 269ms/step - accuracy: 0.9162 - loss: 0.2637 - val_accuracy: 0.8701 - val_loss: 0.4438 - learning_rate: 0.0010
# Epoch 19/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 76s 269ms/step - accuracy: 0.9205 - loss: 0.2473 - val_accuracy: 0.8811 - val_loss: 0.4344 - learning_rate: 0.0010
# Epoch 20/20
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 76s 269ms/step - accuracy: 0.9226 - loss: 0.2461 - val_accuracy: 0.8596 - val_loss: 0.4920 - learning_rate: 0.0010

# %%
# Dégèle
base_model.trainable = True

fine_tune_at = 140  # ResNet50 a environ 175 couches
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# %%
model_efficientb0.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

# %%
history_model2 = model_efficientb0.fit(
    train_ds,
    validation_data=val_ds,
    epochs=40,
    callbacks=[reduceLR, save, early_stop]
)
# Out:
# Epoch 1/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 150s 488ms/step - accuracy: 0.5526 - loss: 1.7927 - val_accuracy: 0.7482 - val_loss: 0.9323 - learning_rate: 1.0000e-05
# Epoch 2/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 481ms/step - accuracy: 0.6887 - loss: 1.1058 - val_accuracy: 0.7746 - val_loss: 0.8092 - learning_rate: 1.0000e-05
# Epoch 3/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 136s 480ms/step - accuracy: 0.7502 - loss: 0.8522 - val_accuracy: 0.8048 - val_loss: 0.7073 - learning_rate: 1.0000e-05
# Epoch 4/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 136s 479ms/step - accuracy: 0.7829 - loss: 0.7086 - val_accuracy: 0.8220 - val_loss: 0.6354 - learning_rate: 1.0000e-05
# Epoch 5/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 136s 481ms/step - accuracy: 0.8092 - loss: 0.6152 - val_accuracy: 0.8317 - val_loss: 0.5912 - learning_rate: 1.0000e-05
# Epoch 6/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 136s 480ms/step - accuracy: 0.8376 - loss: 0.5145 - val_accuracy: 0.8445 - val_loss: 0.5536 - learning_rate: 1.0000e-05
# Epoch 7/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 136s 479ms/step - accuracy: 0.8433 - loss: 0.4836 - val_accuracy: 0.8519 - val_loss: 0.5293 - learning_rate: 1.0000e-05
# Epoch 8/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 136s 481ms/step - accuracy: 0.8641 - loss: 0.4260 - val_accuracy: 0.8571 - val_loss: 0.5044 - learning_rate: 1.0000e-05
# Epoch 9/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 138s 487ms/step - accuracy: 0.8782 - loss: 0.3818 - val_accuracy: 0.8653 - val_loss: 0.4796 - learning_rate: 1.0000e-05
# Epoch 10/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 138s 486ms/step - accuracy: 0.8817 - loss: 0.3622 - val_accuracy: 0.8696 - val_loss: 0.4649 - learning_rate: 1.0000e-05
# Epoch 11/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 489ms/step - accuracy: 0.8928 - loss: 0.3305 - val_accuracy: 0.8758 - val_loss: 0.4486 - learning_rate: 1.0000e-05
# Epoch 12/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 138s 488ms/step - accuracy: 0.8984 - loss: 0.3116 - val_accuracy: 0.8773 - val_loss: 0.4381 - learning_rate: 1.0000e-05
# Epoch 13/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 489ms/step - accuracy: 0.9035 - loss: 0.2969 - val_accuracy: 0.8809 - val_loss: 0.4259 - learning_rate: 1.0000e-05
# Epoch 14/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 489ms/step - accuracy: 0.9059 - loss: 0.2890 - val_accuracy: 0.8835 - val_loss: 0.4190 - learning_rate: 1.0000e-05
# Epoch 15/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 488ms/step - accuracy: 0.9145 - loss: 0.2561 - val_accuracy: 0.8870 - val_loss: 0.4063 - learning_rate: 1.0000e-05
# Epoch 16/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 491ms/step - accuracy: 0.9197 - loss: 0.2486 - val_accuracy: 0.8909 - val_loss: 0.4014 - learning_rate: 1.0000e-05
# Epoch 17/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 488ms/step - accuracy: 0.9298 - loss: 0.2246 - val_accuracy: 0.8911 - val_loss: 0.3945 - learning_rate: 1.0000e-05
# Epoch 18/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 491ms/step - accuracy: 0.9333 - loss: 0.2051 - val_accuracy: 0.8934 - val_loss: 0.3881 - learning_rate: 1.0000e-05
# Epoch 19/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 490ms/step - accuracy: 0.9281 - loss: 0.2093 - val_accuracy: 0.8942 - val_loss: 0.3817 - learning_rate: 1.0000e-05
# Epoch 20/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 491ms/step - accuracy: 0.9315 - loss: 0.2044 - val_accuracy: 0.8978 - val_loss: 0.3747 - learning_rate: 1.0000e-05
# Epoch 21/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 489ms/step - accuracy: 0.9409 - loss: 0.1879 - val_accuracy: 0.8991 - val_loss: 0.3711 - learning_rate: 1.0000e-05
# Epoch 22/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 491ms/step - accuracy: 0.9434 - loss: 0.1725 - val_accuracy: 0.9006 - val_loss: 0.3656 - learning_rate: 1.0000e-05
# Epoch 23/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 489ms/step - accuracy: 0.9450 - loss: 0.1695 - val_accuracy: 0.9019 - val_loss: 0.3605 - learning_rate: 1.0000e-05
# Epoch 24/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 139s 489ms/step - accuracy: 0.9441 - loss: 0.1679 - val_accuracy: 0.9029 - val_loss: 0.3608 - learning_rate: 1.0000e-05
# Epoch 25/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 482ms/step - accuracy: 0.9475 - loss: 0.1580 - val_accuracy: 0.9034 - val_loss: 0.3540 - learning_rate: 1.0000e-05
# Epoch 26/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 484ms/step - accuracy: 0.9505 - loss: 0.1524 - val_accuracy: 0.9050 - val_loss: 0.3470 - learning_rate: 1.0000e-05
# Epoch 27/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 481ms/step - accuracy: 0.9521 - loss: 0.1384 - val_accuracy: 0.9042 - val_loss: 0.3490 - learning_rate: 1.0000e-05
# Epoch 28/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 481ms/step - accuracy: 0.9532 - loss: 0.1374 - val_accuracy: 0.9075 - val_loss: 0.3427 - learning_rate: 1.0000e-05
# Epoch 29/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 482ms/step - accuracy: 0.9559 - loss: 0.1350 - val_accuracy: 0.9080 - val_loss: 0.3401 - learning_rate: 1.0000e-05
# Epoch 30/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 483ms/step - accuracy: 0.9601 - loss: 0.1221 - val_accuracy: 0.9103 - val_loss: 0.3362 - learning_rate: 1.0000e-05
# Epoch 31/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 483ms/step - accuracy: 0.9567 - loss: 0.1285 - val_accuracy: 0.9078 - val_loss: 0.3356 - learning_rate: 1.0000e-05
# Epoch 32/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 483ms/step - accuracy: 0.9638 - loss: 0.1133 - val_accuracy: 0.9098 - val_loss: 0.3340 - learning_rate: 1.0000e-05
# Epoch 33/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 481ms/step - accuracy: 0.9637 - loss: 0.1149 - val_accuracy: 0.9111 - val_loss: 0.3295 - learning_rate: 1.0000e-05
# Epoch 34/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 481ms/step - accuracy: 0.9603 - loss: 0.1152 - val_accuracy: 0.9103 - val_loss: 0.3286 - learning_rate: 1.0000e-05
# Epoch 35/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 482ms/step - accuracy: 0.9659 - loss: 0.1033 - val_accuracy: 0.9119 - val_loss: 0.3283 - learning_rate: 1.0000e-05
# Epoch 36/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 481ms/step - accuracy: 0.9666 - loss: 0.1028 - val_accuracy: 0.9129 - val_loss: 0.3252 - learning_rate: 1.0000e-05
# Epoch 37/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 136s 479ms/step - accuracy: 0.9717 - loss: 0.0931 - val_accuracy: 0.9157 - val_loss: 0.3166 - learning_rate: 1.0000e-05
# Epoch 38/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 136s 479ms/step - accuracy: 0.9687 - loss: 0.0908 - val_accuracy: 0.9173 - val_loss: 0.3153 - learning_rate: 1.0000e-05
# Epoch 39/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 482ms/step - accuracy: 0.9682 - loss: 0.0995 - val_accuracy: 0.9162 - val_loss: 0.3143 - learning_rate: 1.0000e-05
# Epoch 40/40
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 137s 482ms/step - accuracy: 0.9718 - loss: 0.0922 - val_accuracy: 0.9162 - val_loss: 0.3122 - learning_rate: 1.0000e-05

# %%
np.save(rep_model+"CNN_TL_model_efficientnetb0_history.npy", history_model2.history)

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(history_model2.history['loss'])
plt.plot(history_model2.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='right')

plt.subplot(122)
plt.plot(history_model2.history['accuracy'])
plt.plot(history_model2.history['val_accuracy'])
plt.title('Model accuracy by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='right')
plt.show()

# %%
# Fonction pour obtenir les prédictions

def get_predictions_and_labels(dataset):
    true_labels = []
    pred_labels = []

    for images, labels in dataset:

        preds = model_efficientb0.predict(images, verbose=0)
        pred_labels.extend(np.argmax(preds, axis=-1))

        true_labels.extend(labels.numpy())

    return np.array(true_labels), np.array(pred_labels)

y_true, y_pred = get_predictions_and_labels(test_ds)     # test, pas val

# Afficher le rapport de classification
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       123
#            1       0.95      0.87      0.91       115
#            2       0.85      0.89      0.87       148
#            3       0.79      0.88      0.83       122
#            4       0.89      0.73      0.80       109
#            5       0.90      0.81      0.85       145
#            6       0.99      0.99      0.99       124
#            7       0.75      0.90      0.82       135
#            8       0.95      0.89      0.92       122
#            9       0.93      0.89      0.91       125
#           10       0.86      0.95      0.90       128
#           11       0.96      0.94      0.95       129
#           12       0.96      0.93      0.94       125
#           13       0.79      0.99      0.88       139
#           14       0.91      0.84      0.87       126
#           15       0.88      0.90      0.89       128
#           16       0.95      0.92      0.93       133
#           17       0.98      0.90      0.94       107
#           18       0.96      0.93      0.94       128
#           19       0.76      0.86      0.81       131
#           20       0.92      0.90      0.91       125
#           21       1.00      0.99      1.00       120
#           22       0.96      0.95      0.95       129
#           23       1.00      0.96      0.98       133
#           24       0.98      0.98      0.98       117
#           25       0.99      0.99      0.99       137
#           26       0.95      0.93      0.94       134
#           27       0.98      0.90      0.94       159
#           28       0.98      0.98      0.98       120
#           29       0.86      0.88      0.87       153
#
#     accuracy                           0.91      3869
#    macro avg       0.92      0.91      0.91      3869
# weighted avg       0.92      0.91      0.91      3869

# %%
# Affichage de la matrice de confusion

plt.figure(figsize=(15, 15))
cnf_matrix = confusion_matrix(y_true, y_pred, normalize='true')
sns.heatmap(cnf_matrix, cmap='Blues', annot=True, cbar=False, fmt=".2f")
# Out:
# <Axes: >

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive')
np.load("/content/gdrive/My Drive/Colab Notebooks/Champi gras Cake/models3/"+"CNN_TL_model_efficientb0_history.npy", allow_pickle=True)
# Out:
# Mounted at /content/gdrive
# array({'accuracy': [0.5984564423561096, 0.7017089128494263, 0.7570562362670898, 0.7868247032165527, 0.8138368129730225, 0.8415656089782715, 0.8519294261932373, 0.8662623763084412, 0.8754134774208069, 0.884784996509552, 0.8909592032432556, 0.8988974690437317, 0.9048511385917664, 0.9078831076622009, 0.9129548072814941, 0.9195148944854736, 0.9280043840408325, 0.928941547870636, 0.9309812784194946, 0.9350054860115051, 0.9386990070343018, 0.9433296322822571, 0.9446526765823364, 0.945203959941864, 0.9457001090049744, 0.949393630027771, 0.9528114795684814, 0.9555677771568298, 0.9563395977020264, 0.9594818353652954, 0.9589856863021851, 0.9611907601356506, 0.9630650281906128, 0.9644432067871094, 0.9656559824943542, 0.9685226082801819, 0.9705622792243958, 0.9694597721099854, 0.970617413520813, 0.9723814725875854], 'loss': [1.551113486289978, 1.0500309467315674, 0.8158257603645325, 0.6904385089874268, 0.591673731803894, 0.50807124376297, 0.46154072880744934, 0.4198882281780243, 0.38707172870635986, 0.3531505763530731, 0.33395835757255554, 0.3097012937068939, 0.2944868803024292, 0.27825894951820374, 0.26359355449676514, 0.24521581828594208, 0.22365069389343262, 0.2150922268629074, 0.2088572233915329, 0.19662468135356903, 0.18885527551174164, 0.17747806012630463, 0.16762878000736237, 0.16534660756587982, 0.1598646342754364, 0.15353448688983917, 0.13891635835170746, 0.13515087962150574, 0.13518644869327545, 0.12231101840734482, 0.12183653563261032, 0.1197386085987091, 0.11604414135217667, 0.1107545867562294, 0.10541830211877823, 0.09872052818536758, 0.09445325285196304, 0.09289330244064331, 0.09412353485822678, 0.08980879932641983], 'val_accuracy': [0.7482069730758667, 0.7745901346206665, 0.8048155903816223, 0.821977436542511, 0.8317110538482666, 0.8445184230804443, 0.8519467115402222, 0.8570696711540222, 0.8652663826942444, 0.8696209192276001, 0.8757684230804443, 0.8773053288459778, 0.8808913826942444, 0.8834528923034668, 0.8870389461517334, 0.8908811211585999, 0.8911373019218445, 0.8934426307678223, 0.8942110538482666, 0.8977971076965332, 0.8990778923034668, 0.9006147384643555, 0.9018954634666443, 0.9029200673103333, 0.9034323692321777, 0.9049692749977112, 0.9042007923126221, 0.9075307250022888, 0.9080430269241333, 0.9103483557701111, 0.9077869057655334, 0.9098360538482666, 0.9111167788505554, 0.9103483557701111, 0.9118852615356445, 0.9129098653793335, 0.915727436542511, 0.9172643423080444, 0.9162397384643555, 0.9162397384643555], 'val_loss': [0.9323242902755737, 0.8091546297073364, 0.7073215246200562, 0.6354271769523621, 0.591188907623291, 0.5535566806793213, 0.5293136239051819, 0.5044354796409607, 0.47959980368614197, 0.4649476408958435, 0.44855281710624695, 0.4381159245967865, 0.42587119340896606, 0.41898560523986816, 0.406339555978775, 0.4014408588409424, 0.39446520805358887, 0.38805511593818665, 0.38173022866249084, 0.37468692660331726, 0.37114739418029785, 0.36561164259910583, 0.3605005741119385, 0.3608354330062866, 0.35403090715408325, 0.3469691872596741, 0.349038302898407, 0.3427252769470215, 0.34005892276763916, 0.3361690938472748, 0.33564817905426025, 0.3339710533618927, 0.3294816315174103, 0.32861319184303284, 0.32834744453430176, 0.3251856863498688, 0.3165609538555145, 0.31528857350349426, 0.3142591118812561, 0.3122028410434723], 'learning_rate': [9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9.999999747378752e-06, 9. ...
#       dtype=object)
